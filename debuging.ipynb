# %% [markdown]
# Importando libraries

# %%
import pandas as pd
import numpy as np
import talib
from scipy import stats
from funcoes_preco import organize_data, get_efficiency_ratio, get_stats
import plotly.express as px

# %%
file = 'data/PETR4_Daily_202110010000_202201210000.csv'

# %%
symbol_data = organize_data(file)

# %%
symbol_data
# Out:
#          Date   Open   High    Low  Close  TickVolume     Volume  Spread
# 0  2021-10-01  27.12  28.00  27.07  28.00       95980   60983200       0
# 1  2021-10-04  27.76  28.81  27.72  28.77      137267  106937000       0
# 2  2021-10-05  29.00  29.47  28.90  29.44      134750  100469100       0
# 3  2021-10-06  28.95  29.17  28.47  28.71       90807   84599400       0
# 4  2021-10-07  28.70  28.98  28.25  28.60       76271   60469300       0
# ..        ...    ...    ...    ...    ...         ...        ...     ...
# 71 2022-01-17  31.40  31.81  31.25  31.50       72570   35675900       0
# 72 2022-01-18  31.56  31.98  30.97  31.64      110864   78198800       0
# 73 2022-01-19  31.90  32.21  31.44  31.49      131689   77725200       0
# 74 2022-01-20  31.50  32.00  31.11  31.72      145737   85353100       0
# 75 2022-01-21  31.57  31.88  31.53  31.77       85777   60384100       0
#
# [76 rows x 8 columns]

# %%
timeperiod = 20
p_close = symbol_data['Close']

# %%
efficiency_ratio = get_efficiency_ratio(p_close, timeperiod)
mean, stdev, skew, kurtosis = get_stats(p_close, timeperiod)
pct_change = p_close.pct_change()

# %%
eqty_table = pd.DataFrame(zip(symbol_data['Date'], p_close, pct_change, 
                              efficiency_ratio, mean, stdev, skew, kurtosis),
                          columns=['Date', 'Close', 'Percent Change', 
                                   'Efficiency Ratio', 'Mean', 
                                   'Stdev', 'Skew', 'Kurtosis'])

# %%
eqty_table.tail(30)
# Out:
#          Date  Close  Percent Change  Efficiency Ratio       Mean     Stdev  \
# 46 2021-12-09  29.29       -0.002044          0.272122  28.068571  1.264634
# 47 2021-12-10  29.65        0.012291          0.300188  28.221905  1.251809
# 48 2021-12-13  29.47       -0.006071          0.229205  28.365714  1.212854
# 49 2021-12-14  29.12       -0.011876          0.174036  28.467143  1.182242
# 50 2021-12-15  29.30        0.006181          0.258310  28.563810  1.163245
# 51 2021-12-16  29.69        0.013311          0.307918  28.711905  1.097359
# 52 2021-12-17  28.96       -0.024587          0.266484  28.827143  0.984490
# 53 2021-12-20  28.16       -0.027624          0.160285  28.927619  0.782979
# 54 2021-12-21  28.20        0.001420          0.036496  29.015238  0.562720
# 55 2021-12-22  28.16       -0.001418          0.021967  29.032381  0.529968
# 56 2021-12-23  28.33        0.006037          0.140830  29.030476  0.532411
# 57 2021-12-27  28.75        0.014825          0.033613  28.989048  0.518596
# 58 2021-12-28  28.78        0.001043          0.095700  29.003810  0.507913
# 59 2021-12-29  28.54       -0.008339          0.137984  28.959524  0.505875
# 60 2021-12-30  28.45       -0.003153          0.176923  28.912857  0.505523
# 61 2022-01-03  29.09        0.022496          0.104735  28.888571  0.483709
# 62 2022-01-04  29.20        0.003781          0.075342  28.928571  0.472957
# 63 2022-01-05  28.07       -0.038699          0.124810  28.895714  0.506318
# 64 2022-01-06  28.05       -0.000713          0.202786  28.855714  0.537415
# 65 2022-01-07  28.18        0.004635          0.191176  28.799524  0.543406
# 66 2022-01-10  28.01       -0.006033          0.203822  28.735714  0.553599
# 67 2022-01-11  28.84        0.029632          0.114894  28.714286  0.540278
# 68 2022-01-12  29.72        0.030513          0.033025  28.717619  0.546224
# 69 2022-01-13  30.32        0.020188          0.150188  28.758095  0.626127
# 70 2022-01-14  31.45        0.037269          0.245154  28.869048  0.847674
# 71 2022-01-17  31.50        0.001590          0.209491  28.973810  1.014075
# 72 2022-01-18  31.64        0.004444          0.319428  29.066667  1.154904
# 73 2022-01-19  31.49       -0.004741          0.426376  29.187143  1.264275
# 74 2022-01-20  31.72        0.007304          0.486188  29.356667  1.350892
# 75 2022-01-21  31.77        0.001576          0.497931  29.526667  1.417618
#
#         Skew  Kurtosis
# 46 -0.274836 -1.632195
# 47 -0.462960 -1.423460
# 48 -0.678367 -1.077774
# 49 -0.916465 -0.599974
# 50 -1.156790 -0.052596
# 51 -1.458284  1.066789
# 52 -1.847734  3.029254
# 53 -1.830413  4.162039
# 54 -0.670418 -0.830930
# 55 -0.503836 -1.313642
# 56 -0.504377 -1.323575
# 57 -0.370295 -1.368768
# 58 -0.436993 -1.193951
# 59 -0.238081 -1.315982
# 60 -0.033010 -1.373025
# 61 -0.019801 -1.233496
# 62 -0.209147 -1.074384
# 63 -0.208733 -1.246673
# 64 -0.133430 -1.441003
# 65  0.066925 -1.479326
# 66  0.238434 -1.402824
# 67  0.329825 -1.204839
# 68  0.361815 -1.137864
# 69  0.802546  0.084916
# 70  1.538378  2.696202
# 71  1.456098  1.494285
# 72  1.344716  0.630465
# 73  1.077503 -0.359598
# 74  0.836171 -0.978725
# 75  0.614972 -1.398203

# %%
new_data = eqty_table.dropna()

new_data.reset_index(inplace=True)

plot_data = new_data[30000:30200]

plot_test = pd.DataFrame(plot_data['Percent Change'])

# %%
fig = px.line(plot_data, x=plot_data.index, y=plot_data['Close', 'Mean'], title='Close Price')
fig2 = px.line(plot_data, x=plot_data.index, y='Percent Change', title='Percent Change')
fig3 = px.bar(plot_data, x=plot_data.index, y='Efficiency Ratio', 
              title='Efficiency Ratio')
fig4 = px.line(plot_data, x=plot_data.index, y='Mean', title='Mean')
fig5 = px.bar(plot_data, x=plot_data.index, y='Stdev', title='Stdev')
fig6 = px.bar(plot_data, x=plot_data.index, y='Skew', title='Skew')
fig7 = px.bar(plot_data, x=plot_data.index, y='Kurtosis', title='Kurtosis')
fig.show()
fig2.show()
fig3.show()
fig4.show()
#fig5.show()
fig6.show()
fig7.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Close', 'Mean')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14908/2870053522.py in <module>
# ----> 1 fig = px.line(plot_data, x=plot_data.index, y=plot_data['Close', 'Mean'], title='Close Price')
#       2 fig2 = px.line(plot_data, x=plot_data.index, y='Percent Change', title='Percent Change')
#       3 fig3 = px.bar(plot_data, x=plot_data.index, y='Efficiency Ratio',
#       4               title='Efficiency Ratio')
#       5 fig4 = px.line(plot_data, x=plot_data.index, y='Mean', title='Mean')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: ('Close', 'Mean')

# %%
new_data.to_excel('data/new_data.xlsx', index=False)
